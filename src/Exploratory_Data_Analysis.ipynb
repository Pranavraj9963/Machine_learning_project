# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/processed/loan_risk_dataset_corrupted.csv")

print(df.shape)

df.head()
# Out:
# (25750, 35)
#    Unnamed: 0  CustomerID  Age  Gender MaritalStatus     Education  \
# 0           0      112424   36    Male        Single  PostGraduate
# 1           1      108271   25  Female        Single    HighSchool
# 2           2      122724   32    Male        Single      Graduate
# 3           3      112573   30  Female       Married      Graduate
# 4           4      112098   41  Female        Single      Graduate
#
#      Occupation  EmploymentYears  AnnualIncome  MonthlyExpenses  ...  \
# 0      Salaried             25.0     6114208.0           190034  ...
# 1  SelfEmployed             30.0     4487423.0            24602  ...
# 2  SelfEmployed              8.0     7493921.0            60028  ...
# 3       Student             35.0           NaN           187520  ...
# 4      Business             36.0     7929802.0           199257  ...
#
#    MissedEMIs  BankBalance  PropertyValue  Dependents  Region CityTier  \
# 0           3      79209.0     46730799.0           4    East    Tier3
# 1           2     517042.0     15261353.0           0    West    Tier2
# 2           4    1956071.0     39629890.0           4   North    Tier1
# 3           3     912949.0     14425719.0           0    East    Tier3
# 4           3          NaN     43000549.0           4   North    Tier2
#
#    PreviousDefaults  FraudFlag  CustomerSegment  LoanApproved
# 0                 1         No          Regular            No
# 1                 1         No          Regular           Yes
# 2                 0         No          Regular           Yes
# 3                 2         No          Regular           Yes
# 4                 2         No          Regular            No
#
# [5 rows x 35 columns]

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.head()
# Out:
#    CustomerID  Age  Gender MaritalStatus     Education    Occupation  \
# 0      112424   36    Male        Single  PostGraduate      Salaried
# 1      108271   25  Female        Single    HighSchool  SelfEmployed
# 2      122724   32    Male        Single      Graduate  SelfEmployed
# 3      112573   30  Female       Married      Graduate       Student
# 4      112098   41  Female        Single      Graduate      Business
#
#    EmploymentYears  AnnualIncome  MonthlyExpenses    Savings  ...  MissedEMIs  \
# 0             25.0     6114208.0           190034  4591940.0  ...           3
# 1             30.0     4487423.0            24602  8884145.0  ...           2
# 2              8.0     7493921.0            60028  4163611.0  ...           4
# 3             35.0           NaN           187520  9707012.0  ...           3
# 4             36.0     7929802.0           199257    53335.0  ...           3
#
#    BankBalance  PropertyValue  Dependents Region  CityTier  PreviousDefaults  \
# 0      79209.0     46730799.0           4   East     Tier3                 1
# 1     517042.0     15261353.0           0   West     Tier2                 1
# 2    1956071.0     39629890.0           4  North     Tier1                 0
# 3     912949.0     14425719.0           0   East     Tier3                 2
# 4          NaN     43000549.0           4  North     Tier2                 2
#
#    FraudFlag  CustomerSegment  LoanApproved
# 0         No          Regular            No
# 1         No          Regular           Yes
# 2         No          Regular           Yes
# 3         No          Regular           Yes
# 4         No          Regular            No
#
# [5 rows x 34 columns]

# %%
numerical_col = df.select_dtypes(include=["int64","float64"]).columns
print(numerical_col)
# Out:
# Index(['CustomerID', 'Age', 'EmploymentYears', 'AnnualIncome',
#        'MonthlyExpenses', 'Savings', 'Investments', 'ExistingLoans',
#        'ExistingEMI', 'LoanAmount', 'LoanTenure', 'CreditScore',
#        'CreditCardLimit', 'CreditCardUsage', 'CreditUtilization',
#        'TransactionsPerMonth', 'OnlineTransactions', 'ATMWithdrawals',
#        'LatePayments', 'MissedEMIs', 'BankBalance', 'PropertyValue',
#        'Dependents', 'PreviousDefaults'],
#       dtype='str')

# %%
categorical_col = df.select_dtypes(include="object").columns
print(categorical_col)
# Out:
# Index(['Gender', 'MaritalStatus', 'Education', 'Occupation', 'LoanPurpose',
#        'Region', 'CityTier', 'FraudFlag', 'CustomerSegment', 'LoanApproved'],
#       dtype='str')
# C:\Users\Pranavraj\AppData\Local\Temp\ipykernel_26856\937442919.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_col = df.select_dtypes(include="object").columns

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"],bins=20,kde = True)

plt.title("Age Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["AnnualIncome"],bins = 30,kde= True)

plt.title("Annual Income Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['LoanAmount'],bins = 30)

plt.title("Loan Amount Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["CreditScore"], bins=30)

plt.show()

# %%
plt.Figure(figsize=(8,5))

sns.countplot(data = df,x="Gender")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(data = df,x = "Occupation")

plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df,x="Education")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(data=df,x="LoanPurpose")

plt.xticks(rotation=20)

plt.show()

# %%
plt.Figure(figsize=(8,5))

sns.scatterplot(data= df,
                x = "AnnualIncome",
                y ="LoanAmount")

plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    data = df,
    x ="LoanApproved",
    y="CreditScore"
)
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.boxplot(data= df,
            x = "LoanApproved",
            y="AnnualIncome")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="LoanApproved",
    y="LatePayments"
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="LoanApproved",
    y="ExistingLoans"
)

plt.show()

# %%
corr = df.select_dtypes(include = np.number).corr()

# %%
plt.figure(figsize=(16,10))

sns.heatmap(corr,
            annot=True,
            cmap="coolwarm")

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x = df["AnnualIncome"]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x=df["Savings"]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x=df["LoanAmount"]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x ="LoanApproved"
)

plt.show()

print(df["LoanApproved"].value_counts())
# Out:
# LoanApproved
# Yes    18980
# No      6770
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data=df,
    x="FraudFlag"
)

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data = df,
    x = "CustomerSegment"
)

plt.show()

# %%
sample = df.sample(1000, random_state=42)

sns.pairplot(
    sample[[
        "Age","AnnualIncome",
        "LoanAmount","CreditScore","Savings"
    ]]
)
plt.show()
